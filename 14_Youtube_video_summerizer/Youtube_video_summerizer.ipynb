# %% [markdown]
# # Youtube Video Summerizer using Langchain

# %%
import os 
os.environ['GROQ_API_KEY'] = '' # groq api key

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-openai faiss-cpu tiktoken python-dotenv

# %% [markdown]
# # Importing Libraries

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate 
from langchain_huggingface import HuggingFaceEmbeddings

# %% [markdown]
# # Document Ingestion

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled, NoTranscriptFound

# YouTube video ID only, not full URL
video_id = "n5bY1gIq2gU"

try:
    # Create API client
    api = YouTubeTranscriptApi()
    
    # Fetch transcript data for the video
    transcript = api.fetch(video_id, languages=["hi", "en"])

    # Convert transcript objects into a single text string
    text = " ".join(item.text for item in transcript)
    
    # Print full transcript
    print(text)

except TranscriptsDisabled:
    # Raised when captions are disabled by the video owner
    print("Captions are disabled")

except NoTranscriptFound:
    # Raised when no transcript exists for the video
    print("No transcript found")

except Exception as e:
    # Catch any unexpected errors
    print("Error:", e)
# Out:
# I’m excited to announce the release of our latest LangChain Academy
# foundations course, Introduction to LangChain in Python. We’ve entered a new era of AI, one
# where our apps don’t just respond, they think, plan, and act autonomously. Today, we're building agents –
# AI systems that can reason and interact with their environments
# to get real work done. Imagine a team of assistants
# that can summarize your inbox, schedule meetings, and perform
# market research 24/7. In this course, you'll learn to
# build deployment-ready agents like these using LangChain. LangChain is the best way to get started
# with building agents. Together with the community,
# we've learned from production use cases and identified the essential
# components an agent needs. The “create agent” abstraction in LangChain
# captures these qualities in their simplest form. In this course,
# you'll learn how to build agents using this abstraction
# and how to customize them with middleware. The goal of this course is to get
# you building agents right away. As we go, we'll assemble a full team
# of personal assistants, with each module culminating in
# a project to build a new one. In module 1,
# we're starting with the basics. Customizing a language model
# with out-of-the-box arguments and system prompts, before adding tools for it to
# call and short-term memory. Within 30 minutes,
# you'll be building a personal chef that suggests recipes
# based on pictures of your fridge. In module 2, your agent will get
# a little bit more sophisticated as you learn about MCP, customized memory,
# and multi-agent systems. Before you know it, you'll have built
# an entire team of synchronized wedding planners using up-to-date flight
# prices and venue details. Finally, you'll learn how to level up
# your agents beyond the prototype stage using middleware. This will allow you to customize your agent
# with dynamic tools, prompts, and models, introduce human in the loop
# to gate sensitive actions, and summarize long conversations
# to protect your agent's context window. At the end of module 3, you'll be tasked
# with creating an email assistant using middleware
# that can automate your entire inbox. We'll then show you a plug and play chat
# interface you can use to quickly demo these impressive agents. I'm excited for you
# to dive into this new course and learn how to build
# agents with LangChain. You can get started today.

# %%
transcript
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='I’m excited to announce the release', start=0.0, duration=1.71), FetchedTranscriptSnippet(text='of our latest LangChain Academy\nfoundations course,', start=1.71, duration=2.794), FetchedTranscriptSnippet(text='Introduction to LangChain in Python.', start=4.504, duration=2.419), FetchedTranscriptSnippet(text='We’ve entered a new era of AI, one\nwhere our apps don’t just respond,', start=6.923, duration=4.004), FetchedTranscriptSnippet(text='they think, plan, and act autonomously.', start=10.927, duration=3.128), FetchedTranscriptSnippet(text="Today, we're building agents –\nAI systems that can reason", start=14.055, duration=3.629), FetchedTranscriptSnippet(text='and interact with their environments\nto get real work done.', start=17.684, duration=3.42), FetchedTranscriptSnippet(text='Imagine a team of assistants\nthat can summarize your inbox,', start=21.104, duration=3.42), FetchedTranscriptSnippet(text='schedule meetings, and perform\nmarket research 24/7.', start=24.524, duration=3.879), FetchedTranscriptSnippet(text="In this course, you'll learn to\nbuild deployment-ready agents", start=28.403, duration=3.211), FetchedTranscriptSnippet(text='like these using LangChain.', start=31.614, duration=2.128), FetchedTranscriptSnippet(text='LangChain is the best way to get started\nwith building agents.', start=33.742, duration=3.336), FetchedTranscriptSnippet(text="Together with the community,\nwe've learned from production use cases", start=37.078, duration=3.379), FetchedTranscriptSnippet(text='and identified the essential\ncomponents an agent needs.', start=40.457, duration=3.545), FetchedTranscriptSnippet(text='The “create agent” abstraction in LangChain\ncaptures these qualities in their simplest form.', start=44.002, duration=5.297), FetchedTranscriptSnippet(text="In this course,\nyou'll learn how to build agents", start=49.299, duration=2.377), FetchedTranscriptSnippet(text='using this abstraction\nand how to customize them with middleware.', start=51.676, duration=4.088), FetchedTranscriptSnippet(text='The goal of this course is to get\nyou building agents right away.', start=55.764, duration=4.129), FetchedTranscriptSnippet(text="As we go, we'll assemble a full team\nof personal assistants,", start=59.893, duration=3.628), FetchedTranscriptSnippet(text='with each module culminating in\na project to build a new one.', start=63.521, duration=3.837), FetchedTranscriptSnippet(text="In module 1,\nwe're starting with the basics.", start=67.358, duration=2.837), FetchedTranscriptSnippet(text='Customizing a language model\nwith out-of-the-box arguments', start=70.195, duration=2.836), FetchedTranscriptSnippet(text='and system prompts,', start=73.031, duration=1.46), FetchedTranscriptSnippet(text='before adding tools for it to\ncall and short-term memory.', start=74.491, duration=3.003), FetchedTranscriptSnippet(text="Within 30 minutes,\nyou'll be building a personal chef", start=77.494, duration=2.961), FetchedTranscriptSnippet(text='that suggests recipes\nbased on pictures of your fridge.', start=80.455, duration=4.004), FetchedTranscriptSnippet(text='In module 2, your agent will get\na little bit more sophisticated', start=84.459, duration=3.92), FetchedTranscriptSnippet(text='as you learn about MCP, customized memory,\nand multi-agent systems.', start=88.379, duration=4.797), FetchedTranscriptSnippet(text="Before you know it, you'll have built\nan entire team of synchronized", start=93.176, duration=3.587), FetchedTranscriptSnippet(text='wedding planners using up-to-date flight\nprices and venue details.', start=96.763, duration=3.67), FetchedTranscriptSnippet(text="Finally, you'll learn how to level up\nyour agents beyond the prototype stage", start=100.433, duration=4.463), FetchedTranscriptSnippet(text='using middleware.', start=104.896, duration=1.376), FetchedTranscriptSnippet(text='This will allow you to customize your agent\nwith dynamic tools, prompts, and mod ...

# %% [markdown]
# # Text Splitting

# %%
# Convert FetchedTranscript → plain text
transcript_text = " ".join(item.text for item in transcript)

# Chunking
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.create_documents([transcript_text])

# %%
print(type(transcript))       # FetchedTranscript
print(type(transcript_text))  # str
# Out:
# <class 'youtube_transcript_api._transcripts.FetchedTranscript'>
# <class 'str'>

# %%
len(chunks)
# Out:
# 6

# %% [markdown]
# # Embedding Generation and Storing in Vector Store (Faiss)

# %%
emb = HuggingFaceEmbeddings(
        model_name="BAAI/bge-base-en-v1.5",
        model_kwargs={"device": "cpu", "trust_remote_code": True},
        encode_kwargs={"normalize_embeddings": True}
)

# %%
vector_store = FAISS.from_documents(chunks, emb)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '25e030ee-38ff-4670-b86a-c5b9de70ae7b',
#  1: '88420877-d228-4f7f-925f-92888b277665',
#  2: 'e91830cd-9431-41fa-a140-c7c727a2210e',
#  3: '8b7a5de5-6ed4-4066-9025-df9ae88ebfb3',
#  4: '3a42e3a8-e9e5-4734-be9b-d70309aad979',
#  5: '55bd8e2a-cf80-413c-b5b9-07d684d198f1'}

# %%
vector_store.get_by_ids(['4750e96e-4bbb-4958-a72c-fd748819c9f4'])
# Out:
# []

# %% [markdown]
# # Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7d4cc6182180>, search_kwargs={'k': 4})

# %%
retriever.invoke('What is langchain')
# Out:
# [Document(id='25e030ee-38ff-4670-b86a-c5b9de70ae7b', metadata={}, page_content="I’m excited to announce the release of our latest LangChain Academy\nfoundations course, Introduction to LangChain in Python. We’ve entered a new era of AI, one\nwhere our apps don’t just respond, they think, plan, and act autonomously. Today, we're building agents –\nAI systems that can reason and interact with their environments\nto get real work done. Imagine a team of assistants\nthat can summarize your inbox, schedule meetings, and perform\nmarket research 24/7. In this course, you'll learn to"),
#  Document(id='88420877-d228-4f7f-925f-92888b277665', metadata={}, page_content="market research 24/7. In this course, you'll learn to\nbuild deployment-ready agents like these using LangChain. LangChain is the best way to get started\nwith building agents. Together with the community,\nwe've learned from production use cases and identified the essential\ncomponents an agent needs. The “create agent” abstraction in LangChain\ncaptures these qualities in their simplest form. In this course,\nyou'll learn how to build agents using this abstraction"),
#  Document(id='55bd8e2a-cf80-413c-b5b9-07d684d198f1', metadata={}, page_content="with creating an email assistant using middleware\nthat can automate your entire inbox. We'll then show you a plug and play chat\ninterface you can use to quickly demo these impressive agents. I'm excited for you\nto dive into this new course and learn how to build\nagents with LangChain. You can get started today."),
#  Document(id='8b7a5de5-6ed4-4066-9025-df9ae88ebfb3', metadata={}, page_content="call and short-term memory. Within 30 minutes,\nyou'll be building a personal chef that suggests recipes\nbased on pictures of your fridge. In module 2, your agent will get\na little bit more sophisticated as you learn about MCP, customized memory,\nand multi-agent systems. Before you know it, you'll have built\nan entire team of synchronized wedding planners using up-to-date flight\nprices and venue details. Finally, you'll learn how to level up")]

# %% [markdown]
# # Augmentation

# %%
llm = ChatGroq(model='groq/compound', temperature=0.1)

# %%
prompt = PromptTemplate(
    template="""
    You are a helpful assistant.
    Answer Only form the provided transcript context.
    If No found. just say You dont know.
    {context}
    Question: {question}
    """,
    input_variables=['context', 'question']
)

question = 'Is the topic about LangChain? discussed in this video? if yes then what was discussed'
retrieved_docs = retriever.invoke(question)

context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)

# %%
retrieved_docs
# Out:
# [Document(id='25e030ee-38ff-4670-b86a-c5b9de70ae7b', metadata={}, page_content="I’m excited to announce the release of our latest LangChain Academy\nfoundations course, Introduction to LangChain in Python. We’ve entered a new era of AI, one\nwhere our apps don’t just respond, they think, plan, and act autonomously. Today, we're building agents –\nAI systems that can reason and interact with their environments\nto get real work done. Imagine a team of assistants\nthat can summarize your inbox, schedule meetings, and perform\nmarket research 24/7. In this course, you'll learn to"),
#  Document(id='88420877-d228-4f7f-925f-92888b277665', metadata={}, page_content="market research 24/7. In this course, you'll learn to\nbuild deployment-ready agents like these using LangChain. LangChain is the best way to get started\nwith building agents. Together with the community,\nwe've learned from production use cases and identified the essential\ncomponents an agent needs. The “create agent” abstraction in LangChain\ncaptures these qualities in their simplest form. In this course,\nyou'll learn how to build agents using this abstraction"),
#  Document(id='55bd8e2a-cf80-413c-b5b9-07d684d198f1', metadata={}, page_content="with creating an email assistant using middleware\nthat can automate your entire inbox. We'll then show you a plug and play chat\ninterface you can use to quickly demo these impressive agents. I'm excited for you\nto dive into this new course and learn how to build\nagents with LangChain. You can get started today."),
#  Document(id='e91830cd-9431-41fa-a140-c7c727a2210e', metadata={}, page_content="you'll learn how to build agents using this abstraction\nand how to customize them with middleware. The goal of this course is to get\nyou building agents right away. As we go, we'll assemble a full team\nof personal assistants, with each module culminating in\na project to build a new one. In module 1,\nwe're starting with the basics. Customizing a language model\nwith out-of-the-box arguments and system prompts, before adding tools for it to\ncall and short-term memory. Within 30 minutes,")]

# %%
context_text
# Out:
# "I’m excited to announce the release of our latest LangChain Academy\nfoundations course, Introduction to LangChain in Python. We’ve entered a new era of AI, one\nwhere our apps don’t just respond, they think, plan, and act autonomously. Today, we're building agents –\nAI systems that can reason and interact with their environments\nto get real work done. Imagine a team of assistants\nthat can summarize your inbox, schedule meetings, and perform\nmarket research 24/7. In this course, you'll learn to\n\nmarket research 24/7. In this course, you'll learn to\nbuild deployment-ready agents like these using LangChain. LangChain is the best way to get started\nwith building agents. Together with the community,\nwe've learned from production use cases and identified the essential\ncomponents an agent needs. The “create agent” abstraction in LangChain\ncaptures these qualities in their simplest form. In this course,\nyou'll learn how to build agents using this abstraction\n\nwith creating an email assistant using middleware\nthat can automate your entire inbox. We'll then show you a plug and play chat\ninterface you can use to quickly demo these impressive agents. I'm excited for you\nto dive into this new course and learn how to build\nagents with LangChain. You can get started today.\n\nyou'll learn how to build agents using this abstraction\nand how to customize them with middleware. The goal of this course is to get\nyou building agents right away. As we go, we'll assemble a full team\nof personal assistants, with each module culminating in\na project to build a new one. In module 1,\nwe're starting with the basics. Customizing a language model\nwith out-of-the-box arguments and system prompts, before adding tools for it to\ncall and short-term memory. Within 30 minutes,"

# %%
final_prompt = prompt.invoke({'context': context_text, "question":question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n    You are a helpful assistant.\n    Answer Only form the provided transcript context.\n    If No found. just say You dont know.\n    I’m excited to announce the release of our latest LangChain Academy\nfoundations course, Introduction to LangChain in Python. We’ve entered a new era of AI, one\nwhere our apps don’t just respond, they think, plan, and act autonomously. Today, we're building agents –\nAI systems that can reason and interact with their environments\nto get real work done. Imagine a team of assistants\nthat can summarize your inbox, schedule meetings, and perform\nmarket research 24/7. In this course, you'll learn to\n\nmarket research 24/7. In this course, you'll learn to\nbuild deployment-ready agents like these using LangChain. LangChain is the best way to get started\nwith building agents. Together with the community,\nwe've learned from production use cases and identified the essential\ncomponents an agent needs. The “create agent” abstraction in LangChain\ncaptures these qualities in their simplest form. In this course,\nyou'll learn how to build agents using this abstraction\n\nwith creating an email assistant using middleware\nthat can automate your entire inbox. We'll then show you a plug and play chat\ninterface you can use to quickly demo these impressive agents. I'm excited for you\nto dive into this new course and learn how to build\nagents with LangChain. You can get started today.\n\nyou'll learn how to build agents using this abstraction\nand how to customize them with middleware. The goal of this course is to get\nyou building agents right away. As we go, we'll assemble a full team\nof personal assistants, with each module culminating in\na project to build a new one. In module 1,\nwe're starting with the basics. Customizing a language model\nwith out-of-the-box arguments and system prompts, before adding tools for it to\ncall and short-term memory. Within 30 minutes,\n    Question: Is the topic about LangChain? discussed in this video? if yes then what was discussed\n    ")

# %% [markdown]
# # Generation

# %%
ans = llm.invoke(final_prompt)
print(ans.content)
# Out:
# Yes. The transcript discusses LangChain. It explains that the course teaches how to build deployment‑ready agents using LangChain’s “create agent” abstraction, customize language models with out‑of‑the‑box arguments, system prompts, tools, short‑term memory, and middleware (e.g., an email‑assistant that automates your inbox). It also mentions a plug‑and‑play chat interface for demoing these agents.

# %% [markdown]
# # Building a Chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
# concatenate the retrieved_docs, function
def contcatenated_docs(retrieved_docs):
    context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
    return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(contcatenated_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('what is langchain?')
# Out:
# {'context': "I’m excited to announce the release of our latest LangChain Academy\nfoundations course, Introduction to LangChain in Python. We’ve entered a new era of AI, one\nwhere our apps don’t just respond, they think, plan, and act autonomously. Today, we're building agents –\nAI systems that can reason and interact with their environments\nto get real work done. Imagine a team of assistants\nthat can summarize your inbox, schedule meetings, and perform\nmarket research 24/7. In this course, you'll learn to\n\nmarket research 24/7. In this course, you'll learn to\nbuild deployment-ready agents like these using LangChain. LangChain is the best way to get started\nwith building agents. Together with the community,\nwe've learned from production use cases and identified the essential\ncomponents an agent needs. The “create agent” abstraction in LangChain\ncaptures these qualities in their simplest form. In this course,\nyou'll learn how to build agents using this abstraction\n\nwith creating an email assistant using middleware\nthat can automate your entire inbox. We'll then show you a plug and play chat\ninterface you can use to quickly demo these impressive agents. I'm excited for you\nto dive into this new course and learn how to build\nagents with LangChain. You can get started today.\n\nyou'll learn how to build agents using this abstraction\nand how to customize them with middleware. The goal of this course is to get\nyou building agents right away. As we go, we'll assemble a full team\nof personal assistants, with each module culminating in\na project to build a new one. In module 1,\nwe're starting with the basics. Customizing a language model\nwith out-of-the-box arguments and system prompts, before adding tools for it to\ncall and short-term memory. Within 30 minutes,",
#  'question': 'what is langchain?'}

# %%
parser = StrOutputParser()

main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke('Can you summerize the video?')
# Out:
# 'The video describes a LangChain course that teaches you to build agents step‑by‑step.  \n\n* **Module\u202f1** – Basics: customize a language model with arguments and system prompts, then add tools and short‑term memory.  \n* **Module\u202f2** – More advanced features: MCP, customized memory, multi‑agent systems, culminating in a team of synchronized wedding planners that can fetch up‑to‑date flight prices and venue details.  \n* **Module\u202f3** – Level‑up with middleware: add dynamic tools, prompts, and models; introduce human‑in‑the‑loop gating for sensitive actions; summarize long conversations to protect the context window. Projects include a personal‑chef assistant that suggests recipes from fridge photos and an email assistant that can automate an entire inbox.  \n\nThe course also provides a plug‑and‑play chat interface for quickly demoing the agents.'
